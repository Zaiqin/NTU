# %% [markdown]
# # Problem 1 : Predicting CentralAir using SalePrice
#
# In this problem, you will build a Classification Tree model to predict CentralAir using SalePrice and judge its accuracy

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
csv_data = pd.read_csv('train.csv', header = 0)

# %% [markdown]
# #### a) Create appropriate datasets for Train and Test in an 80:20 ratio and fit two Classification Tree models (of max depth 2 and max depth 4) on the Train set to predict CentralAir using SalePrice. Print the tree in each case.

# %%
SalePrice = pd.DataFrame(csv_data['SalePrice']) # Predictor
CentralAir = pd.DataFrame(csv_data['CentralAir']) # Response
# CentralAir: Central Air Conditioning

#80-20 Split
from sklearn.model_selection import train_test_split
CentralAir_train, CentralAir_test, SalePrice_train, SalePrice_test = train_test_split(CentralAir, SalePrice, test_size = 0.2)

# Check the sample sizes
print("Train Set :", CentralAir_train.shape, SalePrice_train.shape)
print("Test Set  :", CentralAir_test.shape, SalePrice_test.shape)

# Import Decision Tree Classifier model from Scikit-Learn
from sklearn.tree import DecisionTreeClassifier
# Plot the trained Decision Tree
from sklearn.tree import plot_tree

# Create a Decision Tree Classifier object
dectree = DecisionTreeClassifier(max_depth = 2)
# Train the Decision Tree Classifier model
dectree.fit(SalePrice_train, CentralAir_train)

# Create a Decision Tree Classifier object
dectree2 = DecisionTreeClassifier(max_depth = 4)
# Train the Decision Tree Classifier model
dectree2.fit(SalePrice_train, CentralAir_train)

f = plt.figure(figsize=(12,3))
plot_tree(dectree, filled=True, rounded=True, 
          feature_names=["SalePrice"], 
          class_names=["No CentralAC","Has CentralAC"])
f = plt.figure(figsize=(12,10))
plot_tree(dectree2, filled=True, rounded=True, 
          feature_names=["SalePrice"], 
          class_names=["No CentralAC","Has CentralAC"])
# Out:
# Train Set : (1168, 1) (1168, 1)
# Test Set  : (292, 1) (292, 1)
# [Text(0.48, 0.9, 'SalePrice <= 107700.0\ngini = 0.12\nsamples = 1168\nvalue = [75, 1093]\nclass = Has CentralAC'),
#  Text(0.22, 0.7, 'SalePrice <= 62750.0\ngini = 0.471\nsamples = 121\nvalue = [46, 75]\nclass = Has CentralAC'),
#  Text(0.08, 0.5, 'SalePrice <= 45650.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = No CentralAC'),
#  Text(0.04, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No CentralAC'),
#  Text(0.12, 0.3, 'SalePrice <= 52250.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = No CentralAC'),
#  Text(0.08, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Has CentralAC'),
#  Text(0.16, 0.1, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = No CentralAC'),
#  Text(0.36, 0.5, 'SalePrice <= 105950.0\ngini = 0.45\nsamples = 111\nvalue = [38, 73]\nclass = Has CentralAC'),
#  Text(0.28, 0.3, 'SalePrice <= 98300.0\ngini = 0.433\nsamples = 101\nvalue = [32, 69]\nclass = Has CentralAC'),
#  Text(0.24, 0.1, 'gini = 0.47\nsamples = 74\nvalue = [28, 46]\nclass = Has CentralAC'),
#  Text(0.32, 0.1, 'gini = 0.252\nsamples = 27\nvalue = [4, 23]\nclass = Has CentralAC'),
#  Text(0.44, 0.3, 'SalePrice <= 107450.0\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = No CentralAC'),
#  Text(0.4, 0.1, 'gini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = No CentralAC'),
#  Text(0.48, 0.1, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Has CentralAC'),
#  Text(0.74, 0.7, 'SalePrice <= 145125.0\ngini = 0.054\nsamples = 1047\nvalue = [29, 1018]\nclass = Has CentralAC'),
#  Text(0.64, 0.5, 'SalePrice <= 144950.0\ngini = 0.124\nsamples = 330\nvalue = [22, 308]\nclass = Has CentralAC'),
#  Text(0.6, 0.3, 'SalePrice <= 141250.0\ngini = 0.111\nsamples = 321\nvalue = [19, 302]\nclass = Has CentralAC'),
#  Text(0.56, 0.1, 'gini = 0.122\nsamples = 292\nvalue = [19, 273]\nclass = Has CentralAC'),
#  Text(0.64, 0.1, 'gini = 0.0\nsamples = 29\nvalue = [0, 29]\nclass = Has CentralAC'),
#  Text(0.68, 0.3, 'gini = 0.444\nsamples = 9\nvalue = [3, 6]\nclass = Has CentralAC'),
#  Text(0.84, 0.5, 'SalePrice <= 167700.0\ngini = 0.019\nsamples = 717\nvalue = [7, 710]\nclass = Has CentralAC'),
#  Text(0.76, 0.3, 'SalePrice <= 167370.0\ngini = 0.047\nsamples = 166\nvalue = [4, 162]\nclass = Has CentralAC'),
#  Text(0.72, 0.1, 'gini = 0.036\nsamples = 163\nvalue = [3, 160]\nclass = Has CentralAC'),
#  Text(0.8, 0.1, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Has CentralAC'),
#  Text(0.92, 0.3, 'SalePrice <= 204950.0\ngini = 0.011\nsamples = 551\nvalue = [3, 548]\nclass = Has CentralAC'),
#  Text(0.88, 0.1, 'gini = 0.0\nsamples = 229\nvalue = [0, 229]\nclass = Has CentralAC'),
#  Text(0.96, 0.1, 'gini = 0.018\nsamples = 322\nvalue = [3, 319]\nclass = Has CentralAC')]

# %% [markdown]
# #### b) Print the confusion matrix on Train set and Test set for both the aforesaid models. Compute and print for both the trees the Classification Accuracy, True Positive Rate, False Positive Rate. Which of the two models is better?

# %%
X_train = SalePrice_train
X_test = SalePrice_test
y_train = CentralAir_train
y_test = CentralAir_test

# Predict Legendary values corresponding to Total
y_train_pred = dectree.predict(X_train)
y_test_pred = dectree.predict(X_test)

import sklearn.metrics as metrics
# Plot the two-way Confusion Matrix
from sklearn.metrics import confusion_matrix

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(10, 2))
cmTrain = confusion_matrix(y_train, y_train_pred)
cmTest = confusion_matrix(y_test, y_test_pred)
sb.heatmap(cmTrain, annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(cmTest, annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset 2 Depths")
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
print("True Positive Rate \t:", cmTrain[1][1]/(cmTrain[1][1]+cmTrain[1][0]))
print("False Positive Rate \t:", cmTrain[0][1]/(cmTrain[0][0]+cmTrain[0][1]))
print()
# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset 2 Depths")
print("Classification Accuracy \t:", dectree.score(X_test, y_test))
print("True Positive Rate \t:", cmTest[1][1]/(cmTest[1][1]+cmTest[1][0]))
print("False Positive Rate \t:", cmTest[0][1]/(cmTest[0][0]+cmTest[0][1]))
# Out:
# Goodness of Fit of Model 	Train Dataset 2 Depths
# Classification Accuracy 	: 0.9409246575342466
# True Positive Rate 	: 0.9981701738334858
# False Positive Rate 	: 0.8933333333333333
#
# Goodness of Fit of Model 	Test Dataset 2 Depths
# Classification Accuracy 	: 0.9452054794520548
# True Positive Rate 	: 0.9963235294117647
# False Positive Rate 	: 0.75

# %%
# Predict Legendary values corresponding to Total
y_train_pred = dectree2.predict(X_train)
y_test_pred = dectree2.predict(X_test)

import sklearn.metrics as metrics

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(10, 2))
cmTrain = confusion_matrix(y_train, y_train_pred)
cmTest = confusion_matrix(y_test, y_test_pred)
sb.heatmap(cmTrain, annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(cmTest, annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset 4 Depths")
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
print("True Positive Rate \t:", cmTrain[1][1]/(cmTrain[1][1]+cmTrain[1][0]))
print("False Positive Rate \t:", cmTrain[0][1]/(cmTrain[0][0]+cmTrain[0][1]))
print()
# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset 4 Depths")
print("Classification Accuracy \t:", dectree.score(X_test, y_test))
print("True Positive Rate \t:", cmTest[1][1]/(cmTest[1][1]+cmTest[1][0]))
print("False Positive Rate \t:", cmTest[0][1]/(cmTest[0][0]+cmTest[0][1]))
# Out:
# Goodness of Fit of Model 	Train Dataset 4 Depths
# Classification Accuracy 	: 0.9409246575342466
# True Positive Rate 	: 0.9972552607502287
# False Positive Rate 	: 0.8266666666666667
#
# Goodness of Fit of Model 	Test Dataset 4 Depths
# Classification Accuracy 	: 0.9452054794520548
# True Positive Rate 	: 0.9852941176470589
# False Positive Rate 	: 0.75

# %% [markdown]
# Max Depth 4 is the better model as it has perfect TPR and lower FPR

# %% [markdown]
# Hints and Pointers
#
# o If you take just the first 80% of the data as train and the next 20% as test, it may not be the best train test split.
#
# o If you want to change the max depth of the tree, check the input parameters needed to instantiate the model.
#
# o Think about the accuracy metrics for a tree carefully to determine which model is better and in which metrics.

# %% [markdown]
# # Problem 2 : Predicting CentralAir using Other Variables
#
# Following the steps from the previous problem, build two new uni-variate Classification Tree models (of max depth 4) to
# predict CentralAir using the variables OverallQual and YearBuilt. Justify which of the variables is the best predictor

# %%
def my_function(p, r):
    pred = pd.DataFrame(csv_data[p]) # Predictor
    res = pd.DataFrame(csv_data[r]) # Response

    # Split the Legendary-Total Dataset into Train and Test
    X_train, X_test, y_train, y_test = train_test_split(pred, res, test_size = 0.2)

    # Decision Tree using Train Data
    dectree = DecisionTreeClassifier(max_depth = 4)  # create the decision tree object
    dectree.fit(X_train, y_train)                    # train the decision tree model

    # Predict Legendary values corresponding to Total
    y_train_pred = dectree.predict(X_train)
    y_test_pred = dectree.predict(X_test)

    # Plot the Confusion Matrix for Train and Test
    f, axes = plt.subplots(1, 2, figsize=(12, 4))
    cmTrain = confusion_matrix(y_train, y_train_pred)
    cmTest = confusion_matrix(y_test, y_test_pred)
    sb.heatmap(cmTrain, annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
    sb.heatmap(cmTest, annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
    
    # Check the Goodness of Fit (on Train Data)
    print("Goodness of Fit of Model \tTrain Dataset 4 Depths")
    print("Classification Accuracy \t:", dectree.score(X_train, y_train))
    print("True Positive Rate \t:", cmTrain[1][1]/(cmTrain[1][1]+cmTrain[1][0]))
    print("False Positive Rate \t:", cmTrain[0][1]/(cmTrain[0][0]+cmTrain[0][1]))
    print()
    # Check the Goodness of Fit (on Test Data)
    print("Goodness of Fit of Model \tTest Dataset 4 Depths")
    print("Classification Accuracy \t:", dectree.score(X_test, y_test))
    print("True Positive Rate \t:", cmTest[1][1]/(cmTest[1][1]+cmTest[1][0]))
    print("False Positive Rate \t:", cmTest[0][1]/(cmTest[0][0]+cmTest[0][1]))

# %%
my_function("OverallQual","CentralAir")
# Out:
# Goodness of Fit of Model 	Train Dataset 4 Depths
# Classification Accuracy 	: 0.9426369863013698
# True Positive Rate 	: 1.0
# False Positive Rate 	: 0.9710144927536232
#
# Goodness of Fit of Model 	Test Dataset 4 Depths
# Classification Accuracy 	: 0.9212328767123288
# True Positive Rate 	: 1.0
# False Positive Rate 	: 0.8846153846153846

# %%
my_function("YearBuilt","CentralAir")
# Out:
# Goodness of Fit of Model 	Train Dataset 4 Depths
# Classification Accuracy 	: 0.9383561643835616
# True Positive Rate 	: 0.9963436928702011
# False Positive Rate 	: 0.918918918918919
#
# Goodness of Fit of Model 	Test Dataset 4 Depths
# Classification Accuracy 	: 0.9246575342465754
# True Positive Rate 	: 0.992619926199262
# False Positive Rate 	: 0.9523809523809523

# %% [markdown]
# OverallQual is the better predictor as the test dataset has a much lower FPR than YearBuilt, it also has a higher TPR than YearBuilt

# %% [markdown]
# # Problem 3 : Understanding the Misclassified Samples
#
# In this problem, you will consider finer details of the tree model and try to isolate the misclassified samples for a model.
#
# #### (a) Print the Classification Tree of max depth 4 that you fit in Problem 1(a). Note that each leaf node of your tree represents a specific partition of your training data, based on certain conditions given by the splits in the tree. Find out which leaf node of this tree has the highest number of False Positives (FP) in the training dataset and print all samples in the Train set (rows from the dataframe) that end up in this leaf node (partition) during fit.

# %%
SalePrice = pd.DataFrame(csv_data['SalePrice']) # Predictor
CentralAir = pd.DataFrame(csv_data['CentralAir']) # Response
# CentralAir: Central Air Conditioning

#80-20 Split
from sklearn.model_selection import train_test_split
CentralAir_train, CentralAir_test, SalePrice_train, SalePrice_test = train_test_split(CentralAir, SalePrice, test_size = 0.2)

# Check the sample sizes
print("Train Set :", CentralAir_train.shape, SalePrice_train.shape)
print("Test Set  :", CentralAir_test.shape, SalePrice_test.shape)

# Import Decision Tree Classifier model from Scikit-Learn
from sklearn.tree import DecisionTreeClassifier
# Plot the trained Decision Tree
from sklearn.tree import plot_tree

# Create a Decision Tree Classifier object
dectree2 = DecisionTreeClassifier(max_depth = 4)
# Train the Decision Tree Classifier model
dectree2.fit(SalePrice_train, CentralAir_train)

f = plt.figure(figsize=(12,10))
plot_tree(dectree2, filled=True, rounded=True, 
          feature_names=["SalePrice"], 
          class_names=["No CentralAC","Has CentralAC"])
# Out:
# Train Set : (1168, 1) (1168, 1)
# Test Set  : (292, 1) (292, 1)
# [Text(0.44, 0.9, 'SalePrice <= 98150.0\ngini = 0.125\nsamples = 1168\nvalue = [78, 1090]\nclass = Has CentralAC'),
#  Text(0.2, 0.7, 'SalePrice <= 62250.0\ngini = 0.495\nsamples = 93\nvalue = [42, 51]\nclass = Has CentralAC'),
#  Text(0.08, 0.5, 'SalePrice <= 46000.0\ngini = 0.26\nsamples = 13\nvalue = [11, 2]\nclass = No CentralAC'),
#  Text(0.04, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No CentralAC'),
#  Text(0.12, 0.3, 'SalePrice <= 52250.0\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = No CentralAC'),
#  Text(0.08, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Has CentralAC'),
#  Text(0.16, 0.1, 'gini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = No CentralAC'),
#  Text(0.32, 0.5, 'SalePrice <= 97500.0\ngini = 0.475\nsamples = 80\nvalue = [31, 49]\nclass = Has CentralAC'),
#  Text(0.28, 0.3, 'SalePrice <= 70450.0\ngini = 0.467\nsamples = 78\nvalue = [29, 49]\nclass = Has CentralAC'),
#  Text(0.24, 0.1, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Has CentralAC'),
#  Text(0.32, 0.1, 'gini = 0.477\nsamples = 74\nvalue = [29, 45]\nclass = Has CentralAC'),
#  Text(0.36, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No CentralAC'),
#  Text(0.68, 0.7, 'SalePrice <= 145250.0\ngini = 0.065\nsamples = 1075\nvalue = [36, 1039]\nclass = Has CentralAC'),
#  Text(0.52, 0.5, 'SalePrice <= 107700.0\ngini = 0.15\nsamples = 379\nvalue = [31, 348]\nclass = Has CentralAC'),
#  Text(0.44, 0.3, 'SalePrice <= 106125.0\ngini = 0.307\nsamples = 37\nvalue = [7, 30]\nclass = Has CentralAC'),
#  Text(0.4, 0.1, 'gini = 0.137\nsamples = 27\nvalue = [2, 25]\nclass = Has CentralAC'),
#  Text(0.48, 0.1, 'gini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = No CentralAC'),
#  Text(0.6, 0.3, 'SalePrice <= 144950.0\ngini = 0.131\nsamples = 342\nvalue = [24, 318]\nclass = Has CentralAC'),
#  Text(0.56, 0.1, 'gini = 0.119\nsamples = 331\nvalue = [21, 310]\nclass = Has CentralAC'),
#  Text(0.64, 0.1, 'gini = 0.397\nsamples = 11\nvalue = [3, 8]\nclass = Has CentralAC'),
#  Text(0.84, 0.5, 'SalePrice <= 167700.0\ngini = 0.014\nsamples = 696\nvalue = [5, 691]\nclass = Has CentralAC'),
#  Text(0.76, 0.3, 'SalePrice <= 167370.0\ngini = 0.039\nsamples = 152\nvalue = [3, 149]\nclass = Has CentralAC'),
#  Text(0.72, 0.1, 'gini = 0.026\nsamples = 149\nvalue = [2, 147]\nclass = Has CentralAC'),
#  Text(0.8, 0.1, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Has CentralAC'),
#  Text(0.92, 0.3, 'SalePrice <= 204875.0\ngini = 0.007\nsamples = 544\nvalue = [2, 542]\nclass = Has CentralAC'),
#  Text(0.88, 0.1, 'gini = 0.0\nsamples = 225\nvalue = [0, 225]\nclass = Has CentralAC'),
#  Text(0.96, 0.1, 'gini = 0.012\nsamples = 319\nvalue = [2, 317]\nclass = Has CentralAC')]

# %% [markdown]
# The leaf node fourth from the left with gini = 0.495 has the highest number of false positives. Highest gini means that it has the highest chance of misclassification, thus for positives which are in blue, this would be the leaf node

# %%
removed = SalePrice_train[SalePrice_train['SalePrice'] <= 98300]
removed = removed[removed['SalePrice'] > 61691.5]
print(removed)
# Out:
#       SalePrice
# 1090      92900
# 1062      90000
# 1218      80500
# 1279      68400
# 155       79000
# ...         ...
# 1022      87000
# 749       98000
# 17        90000
# 386       81000
# 696       89000
#
# [80 rows x 1 columns]

# %% [markdown]
# #### (b) Print ONLY the False Positive cases (rows from the dataframe) from the samples (rows) extracted in part (a).

# %% [markdown]
# Hints and Pointers
#
# o In Part (a), you may print the model in Problem 1(a), or fit the max depth 4 classification tree model once again.
#
# o You may simply “observe” which leaf node has the maximum number of False Positives; no need to code for it.
#
# o Think about how data points (samples) end up in a leaf node based on tree splits; it will help you isolate samples.
#
# o Part (b) is a simple continuation of part (a), where you need to “filter” out the False Positives from the samples.
